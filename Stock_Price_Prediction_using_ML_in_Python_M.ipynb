# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Tesla (1).csv')

# %%
df
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# 3      19.200001
# 4      16.110001
# ...          ...
# 1687  246.169998
# 1688  258.000000
# 1689  255.729996
# 1690  262.049988
# 1691  261.500000
#
# [1692 rows x 7 columns]

# %%
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
df.describe().T
# Out:
#             count          mean           std            min           25%  \
# Open       1692.0  1.324416e+02  9.430992e+01      16.139999  3.000000e+01
# High       1692.0  1.347697e+02  9.569491e+01      16.629999  3.065000e+01
# Low        1692.0  1.299962e+02  9.285523e+01      14.980000  2.921500e+01
# Close      1692.0  1.324287e+02  9.431319e+01      15.800000  2.988500e+01
# Volume     1692.0  4.270741e+06  4.295971e+06  118500.000000  1.194350e+06
# Adj Close  1692.0  1.324287e+02  9.431319e+01      15.800000  2.988500e+01
#
#                     50%           75%           max
# Open       1.563350e+02  2.205575e+02  2.876700e+02
# High       1.623700e+02  2.241000e+02  2.914200e+02
# Low        1.531500e+02  2.171200e+02  2.804000e+02
# Close      1.581600e+02  2.200225e+02  2.860400e+02
# Volume     3.180700e+06  5.662100e+06  3.716390e+07
# Adj Close  1.581600e+02  2.200225e+02  2.860400e+02

# %%
df.nunique()
# Out:
# Date         1692
# Open         1464
# High         1470
# Low          1468
# Close        1528
# Volume       1676
# Adj Close    1528
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1692 non-null   object
#  1   Open       1692 non-null   float64
#  2   High       1692 non-null   float64
#  3   Low        1692 non-null   float64
#  4   Close      1692 non-null   float64
#  5   Volume     1692 non-null   int64
#  6   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.7+ KB

# %%
import seaborn as sns

# %%
sns.histplot(df['Open'])
# Out:
# <Axes: xlabel='Open', ylabel='Count'>

# %%
sns.pairplot(df)

# %%
sns.boxplot(df['Open'])
# Out:
# <Axes: ylabel='Open'>

# %%
sns.histplot(df['Close'])
# Out:
# <Axes: xlabel='Close', ylabel='Count'>

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Close'])
plt.title('Tesla Close Price',fontsize=15)
plt.ylabel('Price in dollars.')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Open'])
plt.title('Tesla Open Price',fontsize=15)
plt.ylabel('Price in dollars.')
plt.show()

# %%
df
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# 3      19.200001
# 4      16.110001
# ...          ...
# 1687  246.169998
# 1688  258.000000
# 1689  255.729996
# 1690  262.049988
# 1691  261.500000
#
# [1692 rows x 7 columns]

# %%
df=df.drop(['Adj Close'],axis=1)

# %%
df
# Out:
#            Date        Open        High         Low       Close    Volume
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
# [1692 rows x 6 columns]

# %%
features=['Open','High','Low','Close','Volume']
plt.subplots(figsize=(15,10))
for i,col in enumerate(features):
  plt.subplot(2,3,i+1)
  sns.distplot(df[col])
plt.show()
# Out:
# <ipython-input-32-354ee1c28665>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-32-354ee1c28665>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-32-354ee1c28665>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-32-354ee1c28665>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-32-354ee1c28665>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])

# %%
plt.subplots(figsize=(20,10))
for i,col in enumerate(features):
  plt.subplot(2,3,i+1)
  sns.boxplot(df[col])
plt.show()

# %%
splitted=df['Date'].str.split('/',expand=True)
df['day']=splitted[1].astype('int')
df['month']=splitted[0].astype('int')
df['year']=splitted[2].astype('int')

df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  day  month  \
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300   29      6
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100   30      6
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800    1      7
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800    2      7
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900    6      7
#
#    year
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010

# %%
df['is_quarter_end']=np.where(df['month']%3==0,1,0)
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  day  month  \
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300   29      6
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100   30      6
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800    1      7
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800    2      7
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900    6      7
#
#    year  is_quarter_end
# 0  2010               1
# 1  2010               1
# 2  2010               0
# 3  2010               0
# 4  2010               0

# %%
data_grouped=df.drop('Date',axis=1).groupby('year').mean()
data_grouped
# Out:
#             Open        High         Low       Close        Volume        day  \
# year
# 2010   23.408000   24.077231   22.646077   23.341846  1.579762e+06  16.030769
# 2011   26.821984   27.380238   26.194167   26.804762  1.290615e+06  15.634921
# 2012   31.203120   31.809160   30.545880   31.168600  1.229796e+06  15.776000
# 2013  104.416428  106.853016  101.779881  104.401230  8.407722e+06  15.650794
# 2014  223.415397  227.449881  219.206111  223.329088  6.913973e+06  15.761905
# 2015  229.831944  233.381666  226.270635  230.042898  4.317792e+06  15.750000
# 2016  210.058452  213.433492  206.286151  209.767262  4.611444e+06  15.682540
# 2017  250.426539  253.969808  247.681539  251.301924  5.323187e+06  13.846154
#
#          month  is_quarter_end
# year
# 2010  9.453846        0.346154
# 2011  6.547619        0.345238
# 2012  6.500000        0.328000
# 2013  6.543651        0.321429
# 2014  6.551587        0.337302
# 2015  6.567460        0.345238
# 2016  6.555556        0.341270
# 2017  1.865385        0.250000

# %%
for i, col in enumerate(['Open','High','Low','Close']):
  plt.subplot(2,2,i+1)
  data_grouped[col].plot.bar()
plt.show()

# %%
df.drop('Date',axis=1).groupby('is_quarter_end').mean()
# Out:
#                       Open        High         Low       Close        Volume  \
# is_quarter_end
# 0               130.813739  133.182620  128.257229  130.797709  4.461581e+06
# 1               135.679982  137.927032  133.455777  135.673269  3.891084e+06
#
#                       day     month         year
# is_quarter_end
# 0               15.686501  6.141208  2013.353464
# 1               15.657244  7.584806  2013.314488

# %%
df['open-close']=df['Open']-df['Close']
df['low-high']=df['Low']-df['High']
df['target']=np.where(df['Close'].shift(-1)>df['Close'],1,0)
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  day  month  \
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300   29      6
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100   30      6
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800    1      7
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800    2      7
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900    6      7
#
#    year  is_quarter_end  open-close  low-high  target
# 0  2010               1   -4.889999 -7.459999       0
# 1  2010               1    1.960001 -7.120001       0
# 2  2010               0    3.040001 -5.650000       0
# 3  2010               0    3.799999 -4.390001       0
# 4  2010               0    3.889999 -4.170000       0

# %%
plt.pie(df['target'].value_counts().values,
        labels=[0, 1], autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df.drop('Date', axis=1).corr() > 0.9, annot=True, cbar=False)
plt.show()

# %%
sns.pairplot(df)

# %%
df
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#       day  month  year  is_quarter_end  open-close   low-high  target
# 0      29      6  2010               1   -4.889999  -7.459999       0
# 1      30      6  2010               1    1.960001  -7.120001       0
# 2       1      7  2010               0    3.040001  -5.650000       0
# 3       2      7  2010               0    3.799999  -4.390001       0
# 4       6      7  2010               0    3.889999  -4.170000       0
# ...   ...    ...   ...             ...         ...        ...     ...
# 1687   13      3  2017               1   -1.349991  -4.070007       1
# 1688   14      3  2017               1  -11.889999 -12.099991       0
# 1689   15      3  2017               1    1.270004  -6.729996       1
# 1690   16      3  2017               1    0.350006  -6.690002       0
# 1691   17      3  2017               1    2.500000  -4.129975       0
#
# [1692 rows x 13 columns]

# %%
features=df[['open-close','low-high','is_quarter_end']]
target=df['target']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
features = scaler.fit_transform(features)

# %%
from sklearn.model_selection import train_test_split

X_train,X_valid,Y_train,Y_valid = train_test_split(features,target, test_size=0.2, random_state=2022)
print(X_train.shape,X_valid.shape)
# Out:
# (1353, 3) (339, 3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred=lr.predict(X_valid)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_valid,Y_pred)
# Out:
# 0.5132743362831859

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred=dtc.predict(X_valid)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_valid,Y_pred)
# Out:
# 0.5103244837758112

# %%
from sklearn.neighbors import KNeighborsClassifier
knc=KNeighborsClassifier()
knc.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred=knc.predict(X_valid)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_valid,Y_pred)
# Out:
# 0.5191740412979351

# %%
import keras
print(keras.__version__)
# Out:
# 3.8.0

# %%
model=keras.Sequential()

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.add(keras.Input(shape=(3,),batch_size=32) )

# %%
model.add(keras.layers.Dense(64,activation='relu'))

# %%
model.add(keras.layers.Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
callback=keras.callbacks.EarlyStopping(monitor='val_loss',patience=3,restore_best_weights=True)

# %%
model.fit(X_train,Y_train,epochs=10,batch_size=32,validation_data=(X_valid,Y_valid),callbacks=[callback])
# Out:
# Epoch 1/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.5333 - loss: 0.6995 - val_accuracy: 0.5162 - val_loss: 0.6934
# Epoch 2/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5152 - loss: 0.6954 - val_accuracy: 0.5133 - val_loss: 0.6941
# Epoch 3/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5150 - loss: 0.6935 - val_accuracy: 0.5133 - val_loss: 0.6947
# Epoch 4/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5138 - loss: 0.6950 - val_accuracy: 0.5044 - val_loss: 0.6943

# %%
model.evaluate(X_valid,Y_valid)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5378 - loss: 0.6891
# [0.6933677196502686, 0.516224205493927]
